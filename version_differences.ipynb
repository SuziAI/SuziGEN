# %%
import json
import numpy as np
import os
import dataclasses
import matplotlib.pyplot as plt
import itertools

@dataclasses.dataclass
class SuzipuAdditionalSymbol:
    ADD_NONE: None = None
    ADD_DA_DUN: str = "DA_DUN"
    ADD_XIAO_ZHU: str = "XIAO_ZHU"
    ADD_DING_ZHU: str = "DING_ZHU"
    ADD_DA_ZHU: str = "DA_ZHU"
    ADD_ZHE: str = "ZHE"
    ADD_YE: str = "YE"

@dataclasses.dataclass
class GongcheMelodySymbol:
    HE: str = "HE"
    XIA_SI: str = "XIA_SI"
    SI: str = "SI"
    XIA_YI: str = "XIA_YI"
    YI: str = "YI"
    SHANG: str = "SHANG"
    GOU: str = "GOU"
    CHE: str = "CHE"
    XIA_GONG: str = "XIA_GONG"
    GONG: str = "GONG"
    XIA_FAN: str = "XIA_FAN"
    FAN: str = "FAN"
    LIU: str = "LIU"
    XIA_WU: str = "XIA_WU"
    WU: str = "WU"
    GAO_WU: str = "GAO_WU"
    
    @classmethod
    def to_simple(cls, symbol):
        try:
            return {
                GongcheMelodySymbol.HE: GongcheMelodySymbol.HE,
                GongcheMelodySymbol.XIA_SI: GongcheMelodySymbol.SI,
                GongcheMelodySymbol.SI: GongcheMelodySymbol.SI,
                GongcheMelodySymbol.XIA_YI: GongcheMelodySymbol.YI,
                GongcheMelodySymbol.YI: GongcheMelodySymbol.YI,
                GongcheMelodySymbol.SHANG: GongcheMelodySymbol.SHANG,
                GongcheMelodySymbol.GOU: GongcheMelodySymbol.GOU,
                GongcheMelodySymbol.CHE: GongcheMelodySymbol.CHE,
                GongcheMelodySymbol.XIA_GONG: GongcheMelodySymbol.GONG,
                GongcheMelodySymbol.GONG: GongcheMelodySymbol.GONG,
                GongcheMelodySymbol.XIA_FAN: GongcheMelodySymbol.FAN,
                GongcheMelodySymbol.FAN: GongcheMelodySymbol.FAN,
                GongcheMelodySymbol.LIU: GongcheMelodySymbol.LIU,
                GongcheMelodySymbol.XIA_WU: GongcheMelodySymbol.WU,
                GongcheMelodySymbol.WU: GongcheMelodySymbol.WU,
                GongcheMelodySymbol.GAO_WU: GongcheMelodySymbol.GAO_WU,
            }[symbol]
        except KeyError:
            return "INVALID"

    @classmethod
    def to_lvlv(cls, symbol):
        try:
            return {
                GongcheMelodySymbol.HE: "黃",
                GongcheMelodySymbol.XIA_SI: "大",
                GongcheMelodySymbol.SI: "太",
                GongcheMelodySymbol.XIA_YI: "夾",
                GongcheMelodySymbol.YI: "姑",
                GongcheMelodySymbol.SHANG: "仲",
                GongcheMelodySymbol.GOU: "蕤",
                GongcheMelodySymbol.CHE: "林",
                GongcheMelodySymbol.XIA_GONG: "夷",
                GongcheMelodySymbol.GONG: "南",
                GongcheMelodySymbol.XIA_FAN: "無",
                GongcheMelodySymbol.FAN: "應",
                GongcheMelodySymbol.LIU: "清黃",
                GongcheMelodySymbol.XIA_WU: "清大",
                GongcheMelodySymbol.WU: "清太",
                GongcheMelodySymbol.GAO_WU: "清夾",
            }[symbol]
        except KeyError:
            return "INVALID"

    @classmethod
    def to_gongche(cls, symbol):
        try:
            return {
                GongcheMelodySymbol.HE: "合",
                GongcheMelodySymbol.XIA_SI: "下四",
                GongcheMelodySymbol.SI: "四",
                GongcheMelodySymbol.XIA_YI: "下一",
                GongcheMelodySymbol.YI: "一",
                GongcheMelodySymbol.SHANG: "上",
                GongcheMelodySymbol.GOU: "勾",
                GongcheMelodySymbol.CHE: "尺",
                GongcheMelodySymbol.XIA_GONG: "下工",
                GongcheMelodySymbol.GONG: "工",
                GongcheMelodySymbol.XIA_FAN: "下凡",
                GongcheMelodySymbol.FAN: "凡",
                GongcheMelodySymbol.LIU: "六",
                GongcheMelodySymbol.XIA_WU: "下五",
                GongcheMelodySymbol.WU: "五",
                GongcheMelodySymbol.GAO_WU: "高五"
            }[symbol]
        except KeyError:
            return "INVALID"

    @classmethod
    def to_index(cls, symbol):
        try:
            return {
                GongcheMelodySymbol.HE: 0,
                GongcheMelodySymbol.XIA_SI: 1,
                GongcheMelodySymbol.SI: 2,
                GongcheMelodySymbol.XIA_YI: 3,
                GongcheMelodySymbol.YI: 4,
                GongcheMelodySymbol.SHANG: 5,
                GongcheMelodySymbol.GOU: 6,
                GongcheMelodySymbol.CHE: 7,
                GongcheMelodySymbol.XIA_GONG: 8,
                GongcheMelodySymbol.GONG: 9,
                GongcheMelodySymbol.XIA_FAN: 10,
                GongcheMelodySymbol.FAN: 11,
                GongcheMelodySymbol.LIU: 12,
                GongcheMelodySymbol.XIA_WU: 13,
                GongcheMelodySymbol.WU: 14,
                GongcheMelodySymbol.GAO_WU: 15
            }[symbol]
        except KeyError:
            return "INVALID"

    @classmethod
    def from_string(cls, str):
        try:
            return {
                "合": "0",
                "下四": "1",
                "四": "2",
                "下一": "3",
                "一": "4",
                "上": "5",
                "勾": "6",
                "尺": "7",
                "下工": "8",
                "工": "9",
                "下凡": "A",
                "凡": "B",
                "六": "C",
                "下五": "D",
                "五": "E",
                "高五": "F",

                "黃": "0",
                "大": "1",
                "太": "2",
                "夾": "3",
                "姑": "4",
                "仲": "5",
                "蕤": "6",
                "林": "7",
                "夷": "8",
                "南": "9",
                "無": "A",
                "應": "B",
                "清黃": "C",
                "清大": "D",
                "清太": "E",
                "清夾": "F",
            }[str]
        except KeyError:
            print(f"'{str}' is not a valid gongche string identifier.")
            return "INVALID"

@dataclasses.dataclass
class Lvlv:
    HUANGZHONG: str = "HUANGZHONG"
    DALV: str = "DALV"
    TAICU: str = "TAICU"
    JIAZHONG: str = "JIAZHONG"
    GUXIAN: str = "GUXIAN"
    ZHONGLV: str = "ZHONGLV"
    RUIBIN: str = "RUIBIN"
    LINZHONG: str = "LINZHONG"
    YIZE: str = "YIZE"
    NANLV: str = "NANLV"
    WUYI: str = "WUYI"
    YINGZHONG: str = "YINGZHONG"

    @classmethod
    def to_name(cls, lvlv):
        try:
            return {
                cls.HUANGZHONG: "黄钟",
                cls.DALV: "大吕",
                cls.TAICU: "太簇",
                cls.JIAZHONG: "夹钟",
                cls.GUXIAN: "姑洗",
                cls.ZHONGLV: "仲吕",
                cls.RUIBIN: "蕤宾",
                cls.LINZHONG: "林钟",
                cls.YIZE: "夷则",
                cls.NANLV: "南吕",
                cls.WUYI: "无射",
                cls.YINGZHONG: "应钟"
            }[lvlv]
        except KeyError:
            print(f"'{lvlv}' is not a valid lülü.")
            return "INVALID"

    @classmethod
    def from_name(cls, string):
        try:
            return {
                "黄钟": cls.HUANGZHONG,
                "大吕": cls.DALV,
                "太簇": cls.TAICU,
                "夹钟": cls.JIAZHONG,
                "姑洗": cls.GUXIAN,
                "仲吕": cls.ZHONGLV,
                "蕤宾": cls.RUIBIN,
                "林钟": cls.LINZHONG,
                "夷则": cls.YIZE,
                "南吕": cls.NANLV,
                "无射": cls.WUYI,
                "应钟": cls.YINGZHONG,
            }[string]
        except KeyError:
            print(f"'{string}' is not a valid lülü name")
            return cls.HUANGZHONG

    @classmethod
    def to_int(cls, lvlv):
        try:
            return {
                cls.HUANGZHONG: 0,
                cls.DALV: 1,
                cls.TAICU: 2,
                cls.JIAZHONG: 3,
                cls.GUXIAN: 4,
                cls.ZHONGLV: 5,
                cls.RUIBIN: 6,
                cls.LINZHONG: 7,
                cls.YIZE: 8,
                cls.NANLV: 9,
                cls.WUYI: 10,
                cls.YINGZHONG: 11,
            }[lvlv]
        except KeyError:
            print(f"'{lvlv}' is not a valid lülü")
            return 0

    @classmethod
    def from_int(cls, int):
        try:
            return {
                0: cls.HUANGZHONG,
                1: cls.DALV,
                2: cls.TAICU,
                3: cls.JIAZHONG,
                4: cls.GUXIAN,
                5: cls.ZHONGLV,
                6: cls.RUIBIN,
                7: cls.LINZHONG,
                8: cls.YIZE,
                9: cls.NANLV,
                10: cls.WUYI,
                11: cls.YINGZHONG,
            }[int]
        except KeyError:
            print(f"'{int}' is not a valid lülü int")
            return cls.HUANGZHONG
        
        
@dataclasses.dataclass
class GongdiaoStep:
    GONG: str = "GONG"
    SHANG: str = "SHANG"
    JUE: str = "JUE"
    BIAN: str = "BIAN"
    ZHI: str = "ZHI"
    YU: str = "YU"
    RUN: str = "RUN"

    @classmethod
    def to_name(cls, gongdiaostep):
        try:
            return {GongdiaoStep.GONG: "宫",
             GongdiaoStep.SHANG: "商",
             GongdiaoStep.JUE: "角",
             GongdiaoStep.BIAN: "变",
             GongdiaoStep.ZHI: "徵",
             GongdiaoStep.YU: "羽",
             GongdiaoStep.RUN: "闰"}[gongdiaostep]
        except KeyError:
            return "INVALID"

    @classmethod
    def from_name(cls, gongdiaostep):
        try:
            return {"宫": GongdiaoStep.GONG,
                    "商": GongdiaoStep.SHANG,
                    "角": GongdiaoStep.JUE,
                    "变": GongdiaoStep.BIAN,
                    "徵": GongdiaoStep.ZHI,
                    "羽": GongdiaoStep.YU,
                    "闰": GongdiaoStep.RUN}[gongdiaostep]
        except KeyError:
            return GongdiaoStep.GONG
    
    @classmethod
    def to_index(cls, gongdiaostep):
        try:
            return {GongdiaoStep.GONG: 0,
             GongdiaoStep.SHANG: 1,
             GongdiaoStep.JUE: 2,
             GongdiaoStep.BIAN: 3,
             GongdiaoStep.ZHI: 4,
             GongdiaoStep.YU: 5,
             GongdiaoStep.RUN: 6}[gongdiaostep]
        except KeyError:
            return "INVALID"
        
        

@dataclasses.dataclass
class ExtendedLvlv:
    HUANGZHONG: str = "HUANGZHONG"
    DALV: str = "DALV"
    TAICU: str = "TAICU"
    JIAZHONG: str = "JIAZHONG"
    GUXIAN: str = "GUXIAN"
    ZHONGLV: str = "ZHONGLV"
    RUIBIN: str = "RUIBIN"
    LINZHONG: str = "LINZHONG"
    YIZE: str = "YIZE"
    NANLV: str = "NANLV"
    WUYI: str = "WUYI"
    YINGZHONG: str = "YINGZHONG"
    HUANGZHONG_QING: str = "HUANGZHONG_QING"
    DALV_QING: str = "DALV_QING"
    TAICU_QING: str = "TAICU_QING"
    JIAZHONG_QING: str = "JIAZHONG_QING"
    ZHE_ZI: str = "ZHE_ZI"

    @classmethod
    def to_gongche_melody_symbol(cls, lvlv):
        return {
            cls.HUANGZHONG: GongcheMelodySymbol.HE,
            cls.DALV: GongcheMelodySymbol.XIA_SI,
            cls.TAICU: GongcheMelodySymbol.SI,
            cls.JIAZHONG: GongcheMelodySymbol.XIA_YI,
            cls.GUXIAN: GongcheMelodySymbol.YI,
            cls.ZHONGLV: GongcheMelodySymbol.SHANG,
            cls.RUIBIN: GongcheMelodySymbol.GOU,
            cls.LINZHONG: GongcheMelodySymbol.CHE,
            cls.YIZE: GongcheMelodySymbol.XIA_GONG,
            cls.NANLV: GongcheMelodySymbol.GONG,
            cls.WUYI: GongcheMelodySymbol.XIA_FAN,
            cls.YINGZHONG: GongcheMelodySymbol.FAN,
            cls.HUANGZHONG_QING: GongcheMelodySymbol.LIU,
            cls.DALV_QING: GongcheMelodySymbol.XIA_WU,
            cls.TAICU_QING: GongcheMelodySymbol.WU,
            cls.JIAZHONG_QING: GongcheMelodySymbol.GAO_WU
        }[lvlv]

    @classmethod
    def to_name(cls, lvlv):
        return {
            cls.HUANGZHONG: "黃",
            cls.DALV: "大",
            cls.TAICU: "太",
            cls.JIAZHONG: "夾",
            cls.GUXIAN: "姑",
            cls.ZHONGLV: "仲",
            cls.RUIBIN: "蕤",
            cls.LINZHONG: "林",
            cls.YIZE: "夷",
            cls.NANLV: "南",
            cls.WUYI: "無",
            cls.YINGZHONG: "應",
            cls.HUANGZHONG_QING: "清黃",
            cls.DALV_QING: "清大",
            cls.TAICU_QING: "清太",
            cls.JIAZHONG_QING: "清夹",
            cls.ZHE_ZI: "字折",
        }[lvlv]

    @classmethod
    def from_name(cls, lvlv):
        return {
            "黃": cls.HUANGZHONG,
            "大": cls.DALV,
            "太": cls.TAICU,
            "夾": cls.JIAZHONG,
            "姑": cls.GUXIAN,
            "仲": cls.ZHONGLV,
            "蕤": cls.RUIBIN,
            "林": cls.LINZHONG,
            "夷": cls.YIZE,
            "南": cls.NANLV,
            "無": cls.WUYI,
            "應": cls.YINGZHONG,
            "清黃": cls.HUANGZHONG_QING,
            "清大": cls.DALV_QING,
            "清太": cls.TAICU_QING,
            "清夹": cls.JIAZHONG_QING,
            "字折": cls.ZHE_ZI,
        }[lvlv]

        
class GongdiaoMode:
    def __init__(self, name, chinese_name, tone_inventory: str, final_note: str):
        self.name = name
        self.chinese_name = chinese_name
        self.gong_lvlv = tone_inventory
        self.final_note = final_note

    def check_if_pitch_belongs_to_mode(self, pitch: str, is_suzipu: bool=False):

        if pitch == "" or pitch is None:
            return None
        try:
            pitch_symbol = pitch[0]  # only consider first character
            if is_suzipu:  # in case of suzipu, we must convert it to the pitch which is meant first
                pitch_symbol = self.convert_pitch(pitch_symbol)
            return tone_inventory_check_pitch(self.gong_lvlv, pitch_symbol)
        except:
            return None

    def convert_pitch(self, pitch):
        return tone_inventory_convert_pitch(self.gong_lvlv, pitch)

    def convert_pitches_in_list(self, original_list):
        new_list = []
        for idx in range(len(original_list)):
            try:
                if "secondary" in original_list[idx].keys():
                    new_list.append({"pitch": self.convert_pitch(original_list[idx]["pitch"]), "secondary": original_list[idx]["secondary"]})
                else:
                    new_list.append({"pitch": self.convert_pitch(original_list[idx]["pitch"])})
            except AttributeError:
                new_list.append({"pitch": None})
        return new_list

    def get_properties(self):
        return {"gong_lvlv": self.gong_lvlv, "final_note": self.final_note}


@dataclasses.dataclass
class GongdiaoModeList:
    NO_MODE: GongdiaoMode = GongdiaoMode("*No Mode", "*没有调式", None, None)

    BAN_SHE_DIAO: GongdiaoMode = GongdiaoMode("Ban She Diao", "般涉调", Lvlv.HUANGZHONG, GongdiaoStep.YU)
    DA_SHI_JUE: GongdiaoMode = GongdiaoMode("Da Shi Jue", "大食角", Lvlv.HUANGZHONG, GongdiaoStep.RUN)
    ZHENG_GONG: GongdiaoMode= GongdiaoMode("Zheng Gong", "正宫", Lvlv.HUANGZHONG, GongdiaoStep.GONG)
    DA_SHI_DIAO: GongdiaoMode = GongdiaoMode("Da Shi Diao", "大食调", Lvlv.HUANGZHONG, GongdiaoStep.SHANG)

    HUANG_ZHONG_JUE: GongdiaoMode = GongdiaoMode("*Huang Zhong Jue", "黄钟角", Lvlv.HUANGZHONG, GongdiaoStep.JUE)
    HUANG_ZHONG_ZHI: GongdiaoMode = GongdiaoMode("*Huang Zhong Zhi", "黄钟徵", Lvlv.HUANGZHONG, GongdiaoStep.ZHI)

    GAO_BAN_SHE_DIAO: GongdiaoMode = GongdiaoMode("Gao Ban She Diao", "高般涉调", Lvlv.DALV, GongdiaoStep.YU)
    GAO_DA_SHI_JUE: GongdiaoMode = GongdiaoMode("Gao Da Shi Jue", "高大食角", Lvlv.DALV, GongdiaoStep.RUN)
    GAO_GONG: GongdiaoMode = GongdiaoMode("Gao Gong", "高宫", Lvlv.DALV, GongdiaoStep.GONG)
    GAO_DA_SHI_DIAO: GongdiaoMode = GongdiaoMode("Gao Da Shi Diao", "高大食调", Lvlv.DALV, GongdiaoStep.SHANG)

    ZHONG_LV_DIAO: GongdiaoMode = GongdiaoMode("Zhong Lü Diao", "中吕调", Lvlv.JIAZHONG, GongdiaoStep.YU)
    SHUANG_JUE: GongdiaoMode = GongdiaoMode("Shuang Jue", "双角", Lvlv.JIAZHONG, GongdiaoStep.RUN)
    ZHONG_LV_GONG: GongdiaoMode = GongdiaoMode("Zhong Lü Gong", "中吕宫", Lvlv.JIAZHONG, GongdiaoStep.GONG)
    SHUANG_DIAO: GongdiaoMode = GongdiaoMode("Shuang Diao", "双调", Lvlv.JIAZHONG, GongdiaoStep.SHANG)

    ZHENG_PING_DIAO: GongdiaoMode = GongdiaoMode("Zheng Ping Diao", "正平调", Lvlv.ZHONGLV, GongdiaoStep.YU)
    XIAO_SHI_JUE: GongdiaoMode = GongdiaoMode("Xiao Shi Jue", "小食角", Lvlv.ZHONGLV, GongdiaoStep.RUN)
    DAO_GONG: GongdiaoMode = GongdiaoMode("Dao Gong", "道宫", Lvlv.ZHONGLV, GongdiaoStep.GONG)
    XIAO_SHI_DIAO: GongdiaoMode = GongdiaoMode("Xiao Shi Diao", "小食调", Lvlv.ZHONGLV, GongdiaoStep.SHANG)

    NAN_LV_DIAO: GongdiaoMode = GongdiaoMode("Nan Lü Diao", "南吕调", Lvlv.LINZHONG, GongdiaoStep.YU)  # also 高平调
    XIE_ZHI_JUE: GongdiaoMode = GongdiaoMode("Xie Zhi Jue", "歇指角", Lvlv.LINZHONG, GongdiaoStep.RUN)
    NAN_LV_GONG: GongdiaoMode = GongdiaoMode("Nan Lü Gong", "南吕宫", Lvlv.LINZHONG, GongdiaoStep.GONG)
    XIE_ZHI_DIAO: GongdiaoMode = GongdiaoMode("Xie Zhi Diao", "歇指调", Lvlv.LINZHONG, GongdiaoStep.SHANG)

    XIAN_LV_DIAO: GongdiaoMode = GongdiaoMode("Xian Lü Diao", "仙吕调", Lvlv.YIZE, GongdiaoStep.YU)
    SHANG_JUE: GongdiaoMode = GongdiaoMode("Shang Jue", "商角", Lvlv.YIZE, GongdiaoStep.RUN)
    XIAN_LV_GONG: GongdiaoMode = GongdiaoMode("Xian Lü Gong", "仙吕宫", Lvlv.YIZE, GongdiaoStep.GONG)
    SHANG_DIAO: GongdiaoMode = GongdiaoMode("Shang Diao", "商调", Lvlv.YIZE, GongdiaoStep.SHANG)

    HUANG_ZHONG_DIAO: GongdiaoMode = GongdiaoMode("Huang Zhong Diao", "黄钟调", Lvlv.WUYI, GongdiaoStep.YU)
    YUE_JUE: GongdiaoMode = GongdiaoMode("Yue Jue", "越角", Lvlv.WUYI, GongdiaoStep.RUN)
    HUANG_ZHONG_GONG: GongdiaoMode = GongdiaoMode("Huang Zhong Gong", "黄钟宫", Lvlv.WUYI, GongdiaoStep.GONG)
    YUE_DIAO: GongdiaoMode = GongdiaoMode("Yue Diao", "越调", Lvlv.WUYI, GongdiaoStep.SHANG)

    @classmethod
    def from_string(cls, string):
        for mode in dataclasses.astuple(cls()):
            if string == mode.name or string == mode.chinese_name:
                return mode
        NO_MODE = GongdiaoMode("!!! NO MODE !!!", "！！！没有宫调！！！", Lvlv.HUANGZHONG, GongdiaoStep.GONG)
        #print(f"Could not construct mode from string '{string}'. Returned {cls.NO_MODE.name} instead.")  # TODO: activate?
        return NO_MODE

    @classmethod
    def from_properties(cls, mode_properties):
        try:
            gong_lvlv = mode_properties["gong_lvlv"]
            final_note = mode_properties["final_note"]

            for mode in dataclasses.astuple(cls()):  # first, check if there is already a name stored for this mode
                if mode.gong_lvlv == gong_lvlv and mode.final_note == final_note:
                    return mode

            # otherwise, construct a name for it
            return GongdiaoMode(f"{Lvlv.to_name(gong_lvlv)}均 -- final：{final_note}", f"{Lvlv.to_name(gong_lvlv)}均 -- final：{final_note}", gong_lvlv, final_note)
        except (KeyError, TypeError):
            return GongdiaoModeList.NO_MODE


def get_tone_inventory(lvlv):
    def rotate_list_right(l, idx):
        return [l[(index - idx + len(l)) % len(l)] for index in range(len(l))]

    def extend_tone_inventory(l):
        return l + l[0:4]

    huang_zhong_gong = [GongdiaoStep.GONG, None, GongdiaoStep.SHANG, None, GongdiaoStep.JUE, None, GongdiaoStep.BIAN, GongdiaoStep.ZHI, None, GongdiaoStep.YU, None, GongdiaoStep.RUN]
    return extend_tone_inventory(rotate_list_right(huang_zhong_gong, Lvlv.to_int(lvlv)))

def get_absolute_tone_inventory(lvlv):
        def rotate_list_right(l, idx):
            return [l[(index - idx + len(l)) % len(l)] for index in range(len(l))]

        def extend_tone_inventory(l):
            return l + l[0:4]
        
        if lvlv == Lvlv.LINZHONG:
            huang_zhong_gong = [GongdiaoStep.GONG, None, GongdiaoStep.SHANG, None, GongdiaoStep.JUE, None, None, GongdiaoStep.ZHI, None, GongdiaoStep.YU, None, GongdiaoStep.RUN]
        else:
            huang_zhong_gong = [GongdiaoStep.GONG, None, GongdiaoStep.SHANG, None, GongdiaoStep.JUE, None, GongdiaoStep.BIAN, GongdiaoStep.ZHI, None, GongdiaoStep.YU, None, GongdiaoStep.RUN]
        
        return extend_tone_inventory(rotate_list_right(huang_zhong_gong, Lvlv.to_int(lvlv)))
    
def get_relative_tone_inventory(lvlv):
    if lvlv == Lvlv.LINZHONG: # we need the correct steps, and this one is hexatonic!
        return ['SI', 'YI', 'GOU', 'CHE', 'GONG', 'FAN', None, 'WU']
    else:
        l = []
        for gongche_melody_symbol in dataclasses.astuple(GongcheMelodySymbol()):
            pitch = gongche_melody_symbol if gongche_melody_symbol == strict_tone_inventory_convert_pitch(lvlv, gongche_melody_symbol) else None
            if pitch:
                l.append(GongcheMelodySymbol.to_simple(pitch))
        return l

def tone_inventory_convert_pitch(gong_lvlv, pitch: GongcheMelodySymbol):
    tone_inventory = get_tone_inventory(gong_lvlv)
    def raise_error():
        print(f"Error! Incompatible symbol {pitch} according to tone inventory {tone_inventory}.")
        #raise RuntimeError(f"Error! Incompatible symbol {pitch} according to tone inventory {gong_lvlv}.")

    if pitch == None:
        return None
    # Here, we flip the order, because for Nanlüdiao we need the diatonic steps
    elif pitch == GongcheMelodySymbol.HE:
        #if gong_lvlv[0] is not None:
        return pitch
    elif pitch == GongcheMelodySymbol.XIA_SI or pitch == GongcheMelodySymbol.SI:
        if tone_inventory[2] is not None:
            return GongcheMelodySymbol.SI
        elif tone_inventory[1] is not None:
            return GongcheMelodySymbol.XIA_SI
    elif pitch == GongcheMelodySymbol.XIA_YI or pitch == GongcheMelodySymbol.YI:
        if tone_inventory[4] is not None:
            return GongcheMelodySymbol.YI
        elif tone_inventory[3] is not None:
            return GongcheMelodySymbol.XIA_YI
    elif pitch == GongcheMelodySymbol.SHANG:
        #if gong_lvlv[5] is not None:
        return pitch
    elif pitch == GongcheMelodySymbol.GOU:  # TODO: Check if GOU, having a separate Suzipu symbol, can become CHE
        #if gong_lvlv[6] is not None:
        return pitch
    elif pitch == GongcheMelodySymbol.CHE:
        #if gong_lvlv[7] is not None:
        return pitch
    elif pitch == GongcheMelodySymbol.XIA_GONG or pitch == GongcheMelodySymbol.GONG:
        if tone_inventory[9] is not None:
            return GongcheMelodySymbol.GONG
        elif tone_inventory[8] is not None:
            return GongcheMelodySymbol.XIA_GONG
    elif pitch == GongcheMelodySymbol.XIA_FAN or pitch == GongcheMelodySymbol.FAN:
        if tone_inventory[11] is not None:
            return GongcheMelodySymbol.FAN
        elif tone_inventory[10] is not None:
            return GongcheMelodySymbol.XIA_FAN
    elif pitch == GongcheMelodySymbol.LIU:
        #if gong_lvlv[12] is not None:
        return pitch
    elif pitch == GongcheMelodySymbol.XIA_WU or pitch == GongcheMelodySymbol.WU:
        if tone_inventory[14] is not None:
            return GongcheMelodySymbol.WU
        elif tone_inventory[13] is not None:
            return GongcheMelodySymbol.XIA_WU
    elif pitch == GongcheMelodySymbol.GAO_WU:
        #if gong_lvlv[15] is not None:
        return pitch

    raise_error()
    
def strict_tone_inventory_convert_pitch(gong_lvlv, pitch: GongcheMelodySymbol):
    tone_inventory = get_tone_inventory(gong_lvlv)
    def raise_error():
        print(f"Error! Incompatible symbol {pitch} according to tone inventory {tone_inventory}.")
        #raise RuntimeError(f"Error! Incompatible symbol {pitch} according to tone inventory {gong_lvlv}.")

    if pitch == None:
        return None
    # Here, we flip the order, because for Nanlüdiao we need the diatonic steps
    elif pitch == GongcheMelodySymbol.HE:
        if tone_inventory[0] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_SI or pitch == GongcheMelodySymbol.SI:
        if tone_inventory[2] is not None:
            return GongcheMelodySymbol.SI
        elif tone_inventory[1] is not None:
            return GongcheMelodySymbol.XIA_SI
    elif pitch == GongcheMelodySymbol.XIA_YI or pitch == GongcheMelodySymbol.YI:
        if tone_inventory[4] is not None:
            return GongcheMelodySymbol.YI
        elif tone_inventory[3] is not None:
            return GongcheMelodySymbol.XIA_YI
    elif pitch == GongcheMelodySymbol.SHANG:
        if tone_inventory[5] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.GOU:  # TODO: Check if GOU, having a separate Suzipu symbol, can become CHE
        if tone_inventory[6] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.CHE:
        if tone_inventory[7] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_GONG or pitch == GongcheMelodySymbol.GONG:
        if tone_inventory[9] is not None:
            return GongcheMelodySymbol.GONG
        elif tone_inventory[8] is not None:
            return GongcheMelodySymbol.XIA_GONG
    elif pitch == GongcheMelodySymbol.XIA_FAN or pitch == GongcheMelodySymbol.FAN:
        if tone_inventory[11] is not None:
            return GongcheMelodySymbol.FAN
        elif tone_inventory[10] is not None:
            return GongcheMelodySymbol.XIA_FAN
    elif pitch == GongcheMelodySymbol.LIU:
        if tone_inventory[12] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_WU or pitch == GongcheMelodySymbol.WU:
        if tone_inventory[14] is not None:
            return GongcheMelodySymbol.WU
        elif tone_inventory[13] is not None:
            return GongcheMelodySymbol.XIA_WU
    elif pitch == GongcheMelodySymbol.GAO_WU:
        if tone_inventory[15] is not None:
            return pitch

    return None

def absolute_tone_inventory_convert_pitch(gong_lvlv, pitch: ExtendedLvlv):
    tone_inventory = get_tone_inventory(gong_lvlv)
    def raise_error():
        print(f"Error! Incompatible symbol {pitch} according to tone inventory {tone_inventory}.")
        #raise RuntimeError(f"Error! Incompatible symbol {pitch} according to tone inventory {gong_lvlv}.")

    if pitch == None:
        return None
    # Here, we flip the order, because for Nanlüdiao we need the diatonic steps
    elif pitch == GongcheMelodySymbol.HE:
        if tone_inventory[0] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_SI:
        if tone_inventory[1] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.SI:
        if tone_inventory[2] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_YI:
        if tone_inventory[3] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.YI:
        if tone_inventory[4] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.SHANG:
        if tone_inventory[5] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.GOU:  # TODO: Check if GOU, having a separate Suzipu symbol, can become CHE
        if tone_inventory[6] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.CHE:
        if tone_inventory[7] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_GONG:
        if tone_inventory[8] is not None:
            return pitch
    elif pitch == pitch == GongcheMelodySymbol.GONG:
        if tone_inventory[9] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_FAN:
        if tone_inventory[10] is not None:
            return pitch
    elif pitch == pitch == GongcheMelodySymbol.FAN:
        if tone_inventory[11] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.LIU:
        if tone_inventory[12] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.XIA_WU:
        if tone_inventory[13] is not None:
            return pitch
    elif pitch == pitch == GongcheMelodySymbol.WU:
        if tone_inventory[14] is not None:
            return pitch
    elif pitch == GongcheMelodySymbol.GAO_WU:
        if tone_inventory[15] is not None:
            return pitch

    return None

SimpleSuzipuList = [
    GongcheMelodySymbol.HE,
    GongcheMelodySymbol.SI,
    GongcheMelodySymbol.YI,
    GongcheMelodySymbol.SHANG,
    GongcheMelodySymbol.GOU,
    GongcheMelodySymbol.CHE,
    GongcheMelodySymbol.GONG,
    GongcheMelodySymbol.FAN,
    GongcheMelodySymbol.LIU,
    GongcheMelodySymbol.WU,
    GongcheMelodySymbol.GAO_WU
]

# %%
def get_folder_contents(path, extension=None):
    file_list = []
    try:
        for file_path in sorted(os.listdir(path)):
            file_path = os.path.join(path, file_path)
            if os.path.isdir(file_path):
                file_list += get_folder_contents(file_path, extension)
            if not extension or file_path.lower().endswith(f'.{extension}'):
                file_list.append(file_path)
    except Exception as e:
        print(f"Could not read files from directory {path}. {e}")
    return file_list


def get_title_list(content):
    title_list = []
    for box in content:
        if box["box_type"] == "Title":
            title_list.append(box["text_content"])
    return title_list


def get_title(content):
    title_string = ""
    for box in content:
        if box["box_type"] == "Title":
            title_string += box["text_content"]
    return title_string


def get_lyrics_list(content):
    lyrics_list = []
    for box in content:
        if box["box_type"] == "Music" and box["text_content"] != "":
            lyrics_list.append(box["text_content"])
    return lyrics_list

def get_notation_list(content):
    suzipu_list = []
    for box in content:
        if box["box_type"] == "Music" and box["notation_content"]["pitch"] is not None:
            suzipu_list.append(box["notation_content"])
    return suzipu_list

def get_pauses(lyrics):
    pause_list = []
    for lyric in lyrics:
        if len(lyric) > 1:
            pause_list.append(lyric[1])
        else:
            pause_list.append(None)
    return pause_list


def relative_pitch_to_index(mode_properties, pitch_list):
    tone_inventory = get_tone_inventory(mode_properties["gong_lvlv"])
    index_list = []
    for pitch in pitch_list:
        index_list.append(pitch_to_index[pitch])
    return index_list

def relative_pitch_to_absolute_pitch(mode_properties, relative_pitch_list):
    absolute_pitch_list = []
    for pitch in relative_pitch_list:
        absolute_pitch_list.append(tone_inventory_convert_pitch(mode_properties["gong_lvlv"], pitch))
    return absolute_pitch_list

def absolute_pitch_to_function(mode_properties, absolute_pitch_list):
    tone_inventory = get_tone_inventory(mode_properties["gong_lvlv"])
    function_list = []
    for pitch in absolute_pitch_list:
        function_list.append(tone_inventory[GongcheMelodySymbol.to_index(pitch)])
    return function_list


def absolute_pitch_to_interval(mode_properties, absolute_pitch_list):
    tone_inventory = get_tone_inventory(mode_properties["gong_lvlv"])
    
    ctr = 0
    for idx in range(len(tone_inventory)):
        if tone_inventory[idx] is not None:
            tone_inventory[idx] = ctr
            ctr += 1

    index_list = []
    for pitch in absolute_pitch_list:
        index_list.append(tone_inventory[GongcheMelodySymbol.to_index(pitch)])
    #index_list.reverse()
    index_list = np.array(index_list)
    return index_list[1:]-index_list[:-1]
        
    
def lvlv_to_absolute(content):
    absolute_list = []
    for idx in range(len(content)):
        if content[idx]["pitch"] == ExtendedLvlv.ZHE_ZI and idx > 0:
            pitch = content[idx-1]["pitch"]
        else:
            pitch = content[idx]["pitch"]
        
        absolute_list.append(ExtendedLvlv.to_gongche_melody_symbol(pitch))
    return absolute_list

    
FULL_PAUSE = [".", "。", "?", "？", ":", "："]
PAUSE = [",", "，", "、"]

def open_piece(path):
    with open(path, "r") as file:
        piece = json.load(file)
        del piece["version"]
        del piece["composer"]
        
        if piece["notation_type"] != "Lvlvpu":
            return None
        
        piece["title"] = {}
        piece["title"] = get_title(piece["content"])
        
        piece["lyrics"] = {}
        piece["lyrics"]["list"] = get_lyrics_list(piece["content"])
        piece["lyrics"]["string"] = "".join([char if not (len(char) > 1 and char[1] in FULL_PAUSE) else "".join([char, "\n"]) for char in piece["lyrics"]["list"]])
        
        piece["cipai"] = {}
        piece["cipai"]["pause"] = get_pauses(piece["lyrics"]["list"])
        
        piece["music"] = {}
        #piece["music"]["suzipu"] = get_notation_list(piece["content"])
        #piece["music"]["relative_pitch"] = [note["pitch"] for note in piece["music"]["suzipu"]]
        #piece["music"]["secondary"] = [note["secondary"] for note in piece["music"]["suzipu"]]
        piece["music"]["lvlvpu"] = [p["pitch"] for p in get_notation_list(piece["content"])]
        piece["music"]["absolute_pitch"] = lvlv_to_absolute(get_notation_list(piece["content"]))
        piece["music"]["function"] = absolute_pitch_to_function(piece["mode_properties"], piece["music"]["absolute_pitch"])
        #piece["music"]["interval"] = absolute_pitch_to_interval(piece["mode_properties"], piece["music"]["absolute_pitch"])
        #piece["music"]["reverse_interval"] = -piece["music"]["interval"][::-1]
        
        del piece["content"]
        return piece

def get_pieces_from_path(base_path):
    json_files = get_folder_contents(base_path, "json")
    pieces = []
    for path in json_files:
        piece = open_piece(path)
        if piece is not None:
            pieces.append(piece)
    return pieces

lu_pieces = get_pieces_from_path("../KuiSCIMA/KuiSCIMA/optical_symbolic_dataset/01_lu_edition/json/03_yuejiuge")
zhang_pieces = get_pieces_from_path("../KuiSCIMA/KuiSCIMA/optical_symbolic_dataset/02_zhang_edition/json/03_yuejiuge")
siku_pieces = get_pieces_from_path("../KuiSCIMA/KuiSCIMA/optical_symbolic_dataset/03_siku_quanshu_edition/json/03_yuejiuge")
zhu_pieces = get_pieces_from_path("../KuiSCIMA/KuiSCIMA/optical_symbolic_dataset/04_zhu_edition/json/03_yuejiuge")
shanghai_pieces = get_pieces_from_path("../KuiSCIMA/KuiSCIMA/optical_symbolic_dataset/05_shanghai_manuscript/json/03_yuejiuge")
# Out:
# 'None' is not a valid lülü
# 'None' is not a valid lülü
# 'None' is not a valid lülü
# 'None' is not a valid lülü
# 'None' is not a valid lülü
# 'None' is not a valid lülü

# %%
from collections import Counter

for lu_e, zhang_e, siku_e, zhu_e, shanghai_e in zip(lu_pieces, zhang_pieces, siku_pieces, zhu_pieces, shanghai_pieces):
    lu = lu_e["music"]["lvlvpu"]
    zhang = zhang_e["music"]["lvlvpu"]
    siku = siku_e["music"]["lvlvpu"]
    zhu = zhu_e["music"]["lvlvpu"]
    shanghai = shanghai_e["music"]["lvlvpu"]
    
    for idx in range(len(lu)):
        counter_dict = dict(Counter([lu[idx], zhang[idx], siku[idx], zhu[idx], shanghai[idx]]))
        #if len(counter_dict) > 1:
        print(lu_e["title"], idx, [lu[idx], zhang[idx], siku[idx], zhu[idx], shanghai[idx]])
# Out:
# 帝舜楚調 0 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 1 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 2 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 3 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 4 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 5 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 6 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 7 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 8 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 9 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 10 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 11 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 12 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 13 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 帝舜楚調 14 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 帝舜楚調 15 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 帝舜楚調 16 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 帝舜楚調 17 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 18 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 19 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 20 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 21 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 22 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 23 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 24 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 25 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 26 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 27 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 28 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 29 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 30 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 31 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 32 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 33 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 帝舜楚調 34 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 帝舜楚調 35 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 36 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 37 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 38 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 39 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 40 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 41 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 42 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 43 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 44 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 帝舜楚調 45 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 46 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 47 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 48 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 帝舜楚調 49 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 帝舜楚調 50 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 帝舜楚調 51 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 帝舜楚調 52 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 53 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 54 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 55 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 56 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 57 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 帝舜楚調 58 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 59 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 帝舜楚調 60 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 帝舜楚調 61 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 帝舜楚調 62 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 帝舜楚調 63 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 0 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 1 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 2 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 3 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 4 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 王禹吳調 5 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 6 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 7 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 8 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 王禹吳調 9 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 10 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 11 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 王禹吳調 12 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 13 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 王禹吳調 14 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 15 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 16 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 17 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 18 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 19 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 20 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 21 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 王禹吳調 22 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 23 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 24 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 25 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 王禹吳調 26 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 王禹吳調 27 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 王禹吳調 28 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 29 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 30 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 31 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 32 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 王禹吳調 33 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 34 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 35 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 36 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 37 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 38 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 39 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 王禹吳調 40 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 41 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 42 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 王禹吳調 43 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 王禹吳調 44 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 45 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 46 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 47 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 王禹吳調 48 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 王禹吳調 49 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 50 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 51 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 王禹吳調 52 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 王禹吳調 53 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 王禹吳調 54 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 王禹吳調 55 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 越王越調 0 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 1 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 2 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 3 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 4 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 5 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 6 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 7 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 8 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越王越調 9 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 10 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 11 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 12 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 13 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 14 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 15 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 16 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 17 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 18 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 19 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 20 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 21 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 22 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越王越調 23 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 24 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 25 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 26 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 27 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 28 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 29 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 30 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 31 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 32 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 33 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 34 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 35 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 36 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 37 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 38 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 39 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 40 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 41 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 42 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 43 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越王越調 44 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 45 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 46 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 47 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 48 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 49 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 50 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 51 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 52 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越王越調 53 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越王越調 54 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 55 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 56 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 57 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 58 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 越王越調 59 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 60 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越王越調 61 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 越王越調 62 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 63 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 64 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 65 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 越王越調 66 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越王越調 67 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越王越調 68 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越王越調 69 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越相側商調 0 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 1 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 越相側商調 2 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 3 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 4 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 越相側商調 5 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 6 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 7 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 8 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越相側商調 9 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 10 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 11 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 越相側商調 12 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越相側商調 13 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越相側商調 14 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越相側商調 15 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越相側商調 16 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越相側商調 17 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 18 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 19 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 20 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越相側商調 21 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 越相側商調 22 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 23 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 24 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 越相側商調 25 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 越相側商調 26 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 越相側商調 27 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 越相側商調 28 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 越相側商調 29 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 越相側商調 30 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 越相側商調 31 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 0 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 1 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 項王古平調 2 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 3 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 4 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 5 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 6 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 項王古平調 7 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 8 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 9 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 10 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 11 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 項王古平調 12 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 13 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 14 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 項王古平調 15 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 16 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 17 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 18 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 19 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 項王古平調 20 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 21 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 22 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 23 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 24 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 25 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 26 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 項王古平調 27 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 28 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 29 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 30 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 31 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 項王古平調 32 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 33 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 34 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 35 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 36 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 37 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 38 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 39 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 40 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 41 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 42 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 項王古平調 43 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 44 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 45 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 46 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 47 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 項王古平調 48 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 49 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 項王古平調 50 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 51 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 項王古平調 52 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 53 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 54 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 項王古平調 55 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 項王古平調 56 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 項王古平調 57 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 項王古平調 58 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 項王古平調 59 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 項王古平調 60 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 濤之神雙調 0 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 1 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 2 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 3 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 濤之神雙調 4 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 5 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 6 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 7 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 8 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 9 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 10 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 11 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 濤之神雙調 12 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 13 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 14 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 15 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 16 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 17 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 18 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 19 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 20 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 21 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 濤之神雙調 22 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 23 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 24 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 25 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 26 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 27 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 28 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 29 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 30 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 31 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 32 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 濤之神雙調 33 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 34 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 35 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 36 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 37 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 38 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 39 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 40 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 41 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 42 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 43 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 濤之神雙調 44 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 45 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 46 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 濤之神雙調 47 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 48 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 49 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 50 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 51 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 濤之神雙調 52 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 53 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 54 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 55 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 56 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 57 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 58 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 59 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 60 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 61 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 62 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 63 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 64 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 65 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 濤之神雙調 66 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 67 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 68 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 69 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 濤之神雙調 70 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 濤之神雙調 71 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 濤之神雙調 72 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 73 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 74 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 75 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 76 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 濤之神雙調 77 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 濤之神雙調 78 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 濤之神雙調 79 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 濤之神雙調 80 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 0 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 1 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 2 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 3 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 4 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 5 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 6 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 7 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 曹娥蜀側調 8 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 9 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 10 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 11 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 12 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 13 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 14 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 15 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 16 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 17 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 18 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 19 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 20 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 21 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 22 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 23 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 曹娥蜀側調 24 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 25 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 26 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 曹娥蜀側調 27 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 28 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 曹娥蜀側調 29 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 30 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 31 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 32 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 33 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 34 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 35 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 36 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 37 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 38 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 39 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 40 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 41 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 42 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 曹娥蜀側調 43 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 44 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 45 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 46 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 47 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 48 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 49 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 曹娥蜀側調 50 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 51 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 52 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 曹娥蜀側調 53 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 54 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 55 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 56 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 57 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 58 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 59 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 60 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 曹娥蜀側調 61 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 62 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 63 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 64 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 65 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 66 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 67 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 68 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 69 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 曹娥蜀側調 70 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 71 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 72 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 73 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 曹娥蜀側調 74 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 75 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 曹娥蜀側調 76 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 曹娥蜀側調 77 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 曹娥蜀側調 78 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 曹娥蜀側調 79 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 曹娥蜀側調 80 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 龎將軍高平調 0 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 1 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 2 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 3 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 龎將軍高平調 4 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 5 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 6 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 7 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 8 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 9 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 10 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 11 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 12 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 13 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 14 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 15 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 16 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 17 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 18 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 19 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 20 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 21 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 22 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 23 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 24 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 25 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 26 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 27 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 28 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 29 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 30 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 31 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 32 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 33 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 34 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 35 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 36 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 37 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 38 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 39 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 40 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 41 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 42 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 43 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 44 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 45 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 46 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 47 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 48 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 49 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 50 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 51 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 52 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 53 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 54 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 55 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 56 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 57 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 58 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 59 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 60 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 龎將軍高平調 61 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 龎將軍高平調 62 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 龎將軍高平調 63 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 龎將軍高平調 64 ['LINZHONG', 'NANLV', 'LINZHONG', 'NANLV', 'LINZHONG']
# 龎將軍高平調 65 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 龎將軍高平調 66 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 龎將軍高平調 67 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 龎將軍高平調 68 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 龎將軍高平調 69 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 旌忠中管商調 0 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 1 ['NANLV', 'NANLV', 'NANLV', 'LINZHONG', 'NANLV']
# 旌忠中管商調 2 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 3 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 4 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 5 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 旌忠中管商調 6 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 7 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 8 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 9 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 旌忠中管商調 10 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 11 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 12 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 13 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 旌忠中管商調 14 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 15 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 16 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 17 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 18 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 19 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 旌忠中管商調 20 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 21 ['DALV', 'DALV', 'DALV', 'DALV', 'DALV']
# 旌忠中管商調 22 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 23 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 24 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 25 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 旌忠中管商調 26 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 27 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 旌忠中管商調 28 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 29 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 旌忠中管商調 30 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 31 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 旌忠中管商調 32 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 33 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 34 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 35 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 36 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 37 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 38 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 39 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 旌忠中管商調 40 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 41 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 42 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 43 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 44 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 45 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 46 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 旌忠中管商調 47 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 48 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 49 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 旌忠中管商調 50 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 51 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 52 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 旌忠中管商調 53 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 旌忠中管商調 54 ['DALV', 'DALV', 'DALV', 'DALV', 'DALV']
# 旌忠中管商調 55 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 56 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 旌忠中管商調 57 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 旌忠中管商調 58 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 59 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 旌忠中管商調 60 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 旌忠中管商調 61 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 蔡孝子中管般瞻調 0 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 1 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 2 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 3 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 4 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 5 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 6 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 7 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 8 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 9 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 10 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 11 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 12 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 13 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 14 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 蔡孝子中管般瞻調 15 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 16 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 17 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 18 ['DALV', 'DALV', 'DALV', 'DALV', 'DALV']
# 蔡孝子中管般瞻調 19 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 20 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 21 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 22 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 23 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 24 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 25 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 26 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 27 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 28 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 蔡孝子中管般瞻調 29 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 30 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 31 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 32 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 33 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 34 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 35 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 36 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 37 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 蔡孝子中管般瞻調 38 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 39 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 40 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 41 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 蔡孝子中管般瞻調 42 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 43 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 44 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 45 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 46 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 47 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 48 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 49 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 50 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 51 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 52 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 53 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 54 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 蔡孝子中管般瞻調 55 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 56 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 蔡孝子中管般瞻調 57 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 58 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 59 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 60 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 61 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 62 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 63 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 64 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 65 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 66 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 67 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 蔡孝子中管般瞻調 68 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 69 ['DALV', 'DALV', 'DALV', 'DALV', 'DALV']
# 蔡孝子中管般瞻調 70 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 蔡孝子中管般瞻調 71 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 72 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 73 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 74 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 蔡孝子中管般瞻調 75 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 76 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 77 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 蔡孝子中管般瞻調 78 ['YIZE', 'YIZE', 'YIZE', 'JIAZHONG', 'YIZE']
# 蔡孝子中管般瞻調 79 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 蔡孝子中管般瞻調 80 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 蔡孝子中管般瞻調 81 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 蔡孝子中管般瞻調 82 ['ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI', 'ZHE_ZI']
# 蔡孝子中管般瞻調 83 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 古今譜法 0 ['HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG', 'HUANGZHONG']
# 古今譜法 1 ['DALV', 'DALV', 'DALV', 'DALV', 'DALV']
# 古今譜法 2 ['TAICU', 'TAICU', 'TAICU', 'TAICU', 'TAICU']
# 古今譜法 3 ['JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG', 'JIAZHONG']
# 古今譜法 4 ['GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN', 'GUXIAN']
# 古今譜法 5 ['ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV', 'ZHONGLV']
# 古今譜法 6 ['RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN', 'RUIBIN']
# 古今譜法 7 ['LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG', 'LINZHONG']
# 古今譜法 8 ['YIZE', 'YIZE', 'YIZE', 'YIZE', 'YIZE']
# 古今譜法 9 ['NANLV', 'NANLV', 'NANLV', 'NANLV', 'NANLV']
# 古今譜法 10 ['WUYI', 'WUYI', 'WUYI', 'WUYI', 'WUYI']
# 古今譜法 11 ['YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG', 'YINGZHONG']
# 古今譜法 12 ['HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING', 'HUANGZHONG_QING']
# 古今譜法 13 ['DALV_QING', 'DALV_QING', 'DALV_QING', 'DALV_QING', 'DALV_QING']
# 古今譜法 14 ['TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING', 'TAICU_QING']
# 古今譜法 15 ['JIAZHONG_QING', 'JIAZHONG_QING', 'JIAZHONG_QING', 'JIAZHONG_QING', 'JIAZHONG_QING']
